# %%
#import library
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
#import the winequality-red.csv file
ds=pd.read_csv('winequality-red.csv')
ds
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    11.0                  34.0  0.99780  3.51       0.56
# 1                    25.0                  67.0  0.99680  3.20       0.68
# 2                    15.0                  54.0  0.99700  3.26       0.65
# 3                    17.0                  60.0  0.99800  3.16       0.58
# 4                    11.0                  34.0  0.99780  3.51       0.56
# ...                   ...                   ...      ...   ...        ...
# 1594                 32.0                  44.0  0.99490  3.45       0.58
# 1595                 39.0                  51.0  0.99512  3.52       0.76
# 1596                 29.0                  40.0  0.99574  3.42       0.75
# 1597                 32.0                  44.0  0.99547  3.57       0.71
# 1598                 18.0                  42.0  0.99549  3.39       0.66
#
#       alcohol  quality
# 0         9.4        5
# 1         9.8        5
# 2         9.8        5
# 3         9.8        6
# 4         9.4        5
# ...       ...      ...
# 1594     10.5        5
# 1595     11.2        6
# 1596     11.0        6
# 1597     10.2        5
# 1598     11.0        6
#
# [1599 rows x 12 columns]

# %%
#Loading in dataFrame
df=pd.DataFrame(data=ds)
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# 3      9.8        6
# 4      9.4        5

# %%
df.tail()
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 1594                 32.0                  44.0  0.99490  3.45       0.58
# 1595                 39.0                  51.0  0.99512  3.52       0.76
# 1596                 29.0                  40.0  0.99574  3.42       0.75
# 1597                 32.0                  44.0  0.99547  3.57       0.71
# 1598                 18.0                  42.0  0.99549  3.39       0.66
#
#       alcohol  quality
# 1594     10.5        5
# 1595     11.2        6
# 1596     11.0        6
# 1597     10.2        5
# 1598     11.0        6

# %%
df.shape
# Out:
# (1599, 12)

# %%
df.dtypes
# Out:
# fixed acidity           float64
# volatile acidity        float64
# citric acid             float64
# residual sugar          float64
# chlorides               float64
# free sulfur dioxide     float64
# total sulfur dioxide    float64
# density                 float64
# pH                      float64
# sulphates               float64
# alcohol                 float64
# quality                   int64
# dtype: object

# %%
df.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %%
df['quality'].unique()
# Out:
# array([5, 6, 7, 4, 8, 3], dtype=int64)

# %% [markdown]
# All columns are numerical

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %%
df.quality.value_counts()
# Out:
# 5    681
# 6    638
# 7    199
# 4     53
# 8     18
# 3     10
# Name: quality, dtype: int64

# %%
df.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
#data has no null values
#no categirical data present all are in float

# %% [markdown]
# ## Data Visualization

# %%
df.hist(bins=25,figsize=(10,10))
# display histogram
plt.show()

# %%
#lets check whether the null values are present in the dataset or not using heatmap
sns.heatmap(df.isnull(),annot=True)
plt.show()

# %%
df.hist(figsize=(15,15))
# Out:
# array([[<AxesSubplot:title={'center':'fixed acidity'}>,
#         <AxesSubplot:title={'center':'volatile acidity'}>,
#         <AxesSubplot:title={'center':'citric acid'}>],
#        [<AxesSubplot:title={'center':'residual sugar'}>,
#         <AxesSubplot:title={'center':'chlorides'}>,
#         <AxesSubplot:title={'center':'free sulfur dioxide'}>],
#        [<AxesSubplot:title={'center':'total sulfur dioxide'}>,
#         <AxesSubplot:title={'center':'density'}>,
#         <AxesSubplot:title={'center':'pH'}>],
#        [<AxesSubplot:title={'center':'sulphates'}>,
#         <AxesSubplot:title={'center':'alcohol'}>,
#         <AxesSubplot:title={'center':'quality'}>]], dtype=object)

# %%
#countplot for quality
sns.countplot(x ='quality', data = df)
 
plt.show()

# %%
sns.pairplot(df,hue='quality')
plt.show()

# %% [markdown]
# No correlation present

# %%
#count of each target variable
from collections import Counter
Counter(df['quality'])
# Out:
# Counter({5: 681, 6: 638, 7: 199, 4: 53, 8: 18, 3: 10})

# %% [markdown]
# ## To check correlation

# %%
plt.figure(figsize=(12,10))
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
df.corr()
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000         -0.256131     0.671703
# volatile acidity          -0.256131          1.000000    -0.552496
# citric acid                0.671703         -0.552496     1.000000
# residual sugar             0.114777          0.001918     0.143577
# chlorides                  0.093705          0.061298     0.203823
# free sulfur dioxide       -0.153794         -0.010504    -0.060978
# total sulfur dioxide      -0.113181          0.076470     0.035533
# density                    0.668047          0.022026     0.364947
# pH                        -0.682978          0.234937    -0.541904
# sulphates                  0.183006         -0.260987     0.312770
# alcohol                   -0.061668         -0.202288     0.109903
# quality                    0.124052         -0.390558     0.226373
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# fixed acidity               0.114777   0.093705            -0.153794
# volatile acidity            0.001918   0.061298            -0.010504
# citric acid                 0.143577   0.203823            -0.060978
# residual sugar              1.000000   0.055610             0.187049
# chlorides                   0.055610   1.000000             0.005562
# free sulfur dioxide         0.187049   0.005562             1.000000
# total sulfur dioxide        0.203028   0.047400             0.667666
# density                     0.355283   0.200632            -0.021946
# pH                         -0.085652  -0.265026             0.070377
# sulphates                   0.005527   0.371260             0.051658
# alcohol                     0.042075  -0.221141            -0.069408
# quality                     0.013732  -0.128907            -0.050656
#
#                       total sulfur dioxide   density        pH  sulphates  \
# fixed acidity                    -0.113181  0.668047 -0.682978   0.183006
# volatile acidity                  0.076470  0.022026  0.234937  -0.260987
# citric acid                       0.035533  0.364947 -0.541904   0.312770
# residual sugar                    0.203028  0.355283 -0.085652   0.005527
# chlorides                         0.047400  0.200632 -0.265026   0.371260
# free sulfur dioxide               0.667666 -0.021946  0.070377   0.051658
# total sulfur dioxide              1.000000  0.071269 -0.066495   0.042947
# density                           0.071269  1.000000 -0.341699   0.148506
# pH                               -0.066495 -0.341699  1.000000  -0.196648
# sulphates                         0.042947  0.148506 -0.196648   1.000000
# alcohol                          -0.205654 -0.496180  0.205633   0.093595
# quality                          -0.185100 -0.174919 -0.057731   0.251397
#
#                        alcohol   quality
# fixed acidity        -0.061668  0.124052
# volatile acidity     -0.202288 -0.390558
# citric acid           0.109903  0.226373
# residual sugar        0.042075  0.013732
# chlorides            -0.221141 -0.128907
# free sulfur dioxide  -0.069408 -0.050656
# total sulfur dioxide -0.205654 -0.185100
# density              -0.496180 -0.174919
# pH                    0.205633 -0.057731
# sulphates             0.093595  0.251397
# alcohol               1.000000  0.476166
# quality               0.476166  1.000000

# %%
plt.figure(figsize=(12,10))
sns.heatmap(df.corr(),annot=True,cmap='tab10')
plt.show()

# %%
#Plot a boxplot to check for Outliers
#Target variable is Quality. So will plot a boxplot each column against target variable
sns.boxplot('quality', 'fixed acidity', data = df)
# Out:
# <AxesSubplot:xlabel='quality', ylabel='fixed acidity'>

# %%
sns.boxplot('quality', 'volatile acidity', data = df)
# Out:
# <AxesSubplot:xlabel='quality', ylabel='volatile acidity'>

# %%
sns.boxplot('quality', 'citric acid', data = df)
# Out:
# <AxesSubplot:xlabel='quality', ylabel='citric acid'>

# %%
sns.boxplot('quality', 'residual sugar', data = df)
# Out:
# <AxesSubplot:xlabel='quality', ylabel='residual sugar'>

# %%
sns.boxplot('quality', 'chlorides', data = df)
# Out:
# <AxesSubplot:xlabel='quality', ylabel='chlorides'>

# %%
sns.boxplot('quality', 'free sulfur dioxide', data = df)
# Out:
# <AxesSubplot:xlabel='quality', ylabel='free sulfur dioxide'>

# %%
sns.boxplot('quality', 'total sulfur dioxide', data = df)
# Out:
# <AxesSubplot:xlabel='quality', ylabel='total sulfur dioxide'>

# %%
sns.boxplot('quality', 'density', data = df)
# Out:
# <AxesSubplot:xlabel='quality', ylabel='density'>

# %%
sns.boxplot('quality', 'pH', data = df)
# Out:
# <AxesSubplot:xlabel='quality', ylabel='pH'>

# %%
sns.boxplot('quality', 'sulphates', data = df)
# Out:
# <AxesSubplot:xlabel='quality', ylabel='sulphates'>

# %%
sns.boxplot('quality', 'alcohol', data = df)
# Out:
# <AxesSubplot:xlabel='quality', ylabel='alcohol'>

# %%
#boxplots show many outliers for quite a few columns
#data.describe()
#fixed acidity - 25% - 7.1 and 50% - 7.9. 
#volatile acididty - similar reasoning
#citric acid - seems to be somewhat uniformly distributed
#residual sugar - min - 0.9, max - 15
#chlorides - same as residual sugar. Min - 0.012, max - 0.611
#free sulfur dioxide, total suflur dioxide - same explanation as above

# %%
df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# min       0.012000             1.000000              6.000000     0.990070
# 25%       0.070000             7.000000             22.000000     0.995600
# 50%       0.079000            14.000000             38.000000     0.996750
# 75%       0.090000            21.000000             62.000000     0.997835
# max       0.611000            72.000000            289.000000     1.003690
#
#                 pH    sulphates      alcohol      quality
# count  1599.000000  1599.000000  1599.000000  1599.000000
# mean      3.311113     0.658149    10.422983     5.636023
# std       0.154386     0.169507     1.065668     0.807569
# min       2.740000     0.330000     8.400000     3.000000
# 25%       3.210000     0.550000     9.500000     5.000000
# 50%       3.310000     0.620000    10.200000     6.000000
# 75%       3.400000     0.730000    11.100000     6.000000
# max       4.010000     2.000000    14.900000     8.000000

# %% [markdown]
# ## Visualizing correlation of feature columns with label column.

# %%
plt.figure(figsize = (20,8))
df.corr()['quality'].sort_values(ascending = False).drop(['quality']).plot(kind='bar',color = 'c')
plt.xlabel('Features',fontsize=15)
plt.ylabel('Quality',fontsize=15)
plt.title('correlation',fontsize = 18)
plt.show()

# %% [markdown]
# 'alchol' and 'volatile acidity have the strongest positive and negative correlations with 'quality' respectively. 'sulphates' and 'total sulfur dioxide'(higher the total sulfur dioxide, lower is the quality) are next in terms of correlation.'Citric acid','density', 'fixed acidity','chlorides','free sulfur dioxide' have weaker correlation while 'residual sugar' and 'pH' have insignificant correlations.

# %% [markdown]
# ## Interpreting Relationship between Dependent Class and Independent Variables

# %%
X = df.drop(columns = ['quality'])
y = df['quality']

# %%
plt.figure(figsize=(20,25),facecolor='white')
plotnum=1
y = df['quality']
for col in X:
    if plotnum<=23:
        plt.subplot(5,5,plotnum)
        sns.stripplot(y,X[col])
        plt.xlabel('quality',fontsize=20)
        plt.ylabel(col,fontsize=20)
    plotnum+=1
plt.tight_layout()

# %% [markdown]
# ## Checking for Skewness and presence of Outliers in Feature Data

# %%
X
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    11.0                  34.0  0.99780  3.51       0.56
# 1                    25.0                  67.0  0.99680  3.20       0.68
# 2                    15.0                  54.0  0.99700  3.26       0.65
# 3                    17.0                  60.0  0.99800  3.16       0.58
# 4                    11.0                  34.0  0.99780  3.51       0.56
# ...                   ...                   ...      ...   ...        ...
# 1594                 32.0                  44.0  0.99490  3.45       0.58
# 1595                 39.0                  51.0  0.99512  3.52       0.76
# 1596                 29.0                  40.0  0.99574  3.42       0.75
# 1597                 32.0                  44.0  0.99547  3.57       0.71
# 1598                 18.0                  42.0  0.99549  3.39       0.66
#
#       alcohol
# 0         9.4
# 1         9.8
# 2         9.8
# 3         9.8
# 4         9.4
# ...       ...
# 1594     10.5
# 1595     11.2
# 1596     11.0
# 1597     10.2
# 1598     11.0
#
# [1599 rows x 11 columns]

# %%
y
# Out:
# 0       5
# 1       5
# 2       5
# 3       6
# 4       5
#        ..
# 1594    5
# 1595    6
# 1596    6
# 1597    5
# 1598    6
# Name: quality, Length: 1599, dtype: int64

# %%
X.skew()
# Out:
# fixed acidity           0.982751
# volatile acidity        0.671593
# citric acid             0.318337
# residual sugar          4.540655
# chlorides               5.680347
# free sulfur dioxide     1.250567
# total sulfur dioxide    1.515531
# density                 0.071288
# pH                      0.193683
# sulphates               2.428672
# alcohol                 0.860829
# dtype: float64

# %% [markdown]
# ## Visualising Data Distribution for every column

# %%
plt.figure(figsize=(20,25),facecolor='white')
plotnum=1
for col in X:
    if plotnum<=11:
        plt.subplot(5,5,plotnum)
        sns.distplot(X[col])
        plt.xlabel(col,fontsize=20)
    plotnum+=1
plt.show()

# %% [markdown]
# 'sulphates', 'fixed acidity', 'volatile acidity', 'residual sugar', 'chlorides','free sulfur dioxide', 'total sulfur dioxide' ,'sulphates', 'alcohol' are all right skewed distributions.

# %% [markdown]
# ## Checking for Outliers

# %%
plt.figure(figsize=(20,25),facecolor='white', )
plotnum=1
for col in X:
    if plotnum<=11:
        plt.subplot(4,4,plotnum)
        sns.boxplot(X[col])
        plt.xlabel(col,fontsize=20)
    plotnum+=1
plt.show()

# %% [markdown]
# From the Boxplots it is evident that 'pH', 'fixed acidity', 'volatile acidity', 'residual sugar', 'chlorides','free sulfur dioxide', 'total sulfur dioxide' ,'sulphates', 'alcohol','citric acid' have outliers present.
#
# Removing Outliers using Z score Method

# %%
df2 = df.copy()

# %%
from scipy.stats import zscore
zscor = zscore(df2)
z_score_abs = np.abs(zscor)

df3 = df2[(z_score_abs < 3).all(axis=1)] #taking 3 as threshold value

# %%
df3.shape
# Out:
# (1451, 12)

# %%
df2.shape
# Out:
# (1599, 12)

# %% [markdown]
# Data loss %:

# %%
loss=(1599-1451)/1599 * 100
loss
# Out:
# 9.255784865540964

# %% [markdown]
# 9.2% Data loss is within acceptable range

# %%
plt.figure(figsize=(20,25),facecolor='white')
plotnum=1
for col in df3:
    if plotnum<=11:
        plt.subplot(4,4,plotnum)
        sns.boxplot(df3[col])
        plt.xlabel(col,fontsize=20)
    plotnum+=1
plt.show()

# %% [markdown]
# Some amount of outliers has been removed.

# %%
X.skew()
# Out:
# fixed acidity           0.982751
# volatile acidity        0.671593
# citric acid             0.318337
# residual sugar          4.540655
# chlorides               5.680347
# free sulfur dioxide     1.250567
# total sulfur dioxide    1.515531
# density                 0.071288
# pH                      0.193683
# sulphates               2.428672
# alcohol                 0.860829
# dtype: float64

# %%
df3.skew()
# Out:
# fixed acidity           0.823934
# volatile acidity        0.380659
# citric acid             0.291297
# residual sugar          2.456107
# chlorides               2.275162
# free sulfur dioxide     0.869250
# total sulfur dioxide    1.183161
# density                 0.055738
# pH                      0.114705
# sulphates               0.891492
# alcohol                 0.758958
# quality                 0.407865
# dtype: float64

# %% [markdown]
#  Skewness has been reduced a little due to outlier removal.
#
# Reducing the skewness further

# %%
df = df3.copy()

# %%
feat = ['fixed acidity','residual sugar','chlorides','free sulfur dioxide','total sulfur dioxide','sulphates','alcohol']

# %%
Skewed_df = df[feat].copy()

# %% [markdown]
# ### Trying Log Transformer Method

# %%
for col in Skewed_df:
    Skewed_df[col] = np.log(Skewed_df[col])

# %%
Skewed_df.skew()
# Out:
# fixed acidity           0.377931
# residual sugar          1.227096
# chlorides               0.496272
# free sulfur dioxide    -0.303456
# total sulfur dioxide   -0.096908
# sulphates               0.342375
# alcohol                 0.592414
# dtype: float64

# %% [markdown]
# ### Trying PowerTransformer method

# %%
from sklearn.preprocessing import PowerTransformer

# %%
powtrans= PowerTransformer(method='yeo-johnson', standardize=True)

# %%
df4 = df[feat].copy()

# %%
df4.skew()
# Out:
# fixed acidity           0.823934
# residual sugar          2.456107
# chlorides               2.275162
# free sulfur dioxide     0.869250
# total sulfur dioxide    1.183161
# sulphates               0.891492
# alcohol                 0.758958
# dtype: float64

# %%
transformed= powtrans.fit_transform(df4)

# %%
type(transformed)
# Out:
# numpy.ndarray

# %%
transformed = pd.DataFrame(transformed, columns=df4.columns) #to convert numpy array back into dataframe

# %%
transformed.skew()
# Out:
# fixed acidity           0.018666
# residual sugar         -0.004606
# chlorides              -0.114658
# free sulfur dioxide    -0.021455
# total sulfur dioxide   -0.005813
# sulphates               0.020799
# alcohol                 0.114658
# dtype: float64

# %%
Skewed_df.skew()
# Out:
# fixed acidity           0.377931
# residual sugar          1.227096
# chlorides               0.496272
# free sulfur dioxide    -0.303456
# total sulfur dioxide   -0.096908
# sulphates               0.342375
# alcohol                 0.592414
# dtype: float64

# %% [markdown]
# On Comparing outputs of Log Transformer method and Power Transformer method, it is determined that Power Transformer gives a better result

# %%
transformed.index = df.index

# %%
df[feat] = transformed[feat]

# %%
X = df.drop(columns = ['quality'])
y = df['quality']

# %%
X.skew()
# Out:
# fixed acidity           0.018666
# volatile acidity        0.380659
# citric acid             0.291297
# residual sugar         -0.004606
# chlorides              -0.114658
# free sulfur dioxide    -0.021455
# total sulfur dioxide   -0.005813
# density                 0.055738
# pH                      0.114705
# sulphates               0.020799
# alcohol                 0.114658
# dtype: float64

# %%
plt.figure(figsize=(20,25),facecolor='white')
plotnum=1
for col in X:
    if plotnum<=11:
        plt.subplot(4,4,plotnum)
        sns.distplot(X[col])
        plt.xlabel(col,fontsize=20)
    plotnum+=1
plt.show()

# %% [markdown]
# Distributions look much more Normalised now

# %% [markdown]
# ## Feature Selection

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler= StandardScaler()
scaled_X = scaler.fit_transform(X)

# %%
scaled_X
# Out:
# array([[-0.46787818,  1.05091371, -1.39039974, ...,  1.37589608,
#         -0.58965734, -1.12042399],
#        [-0.17080535,  2.11933582, -1.39039974, ..., -0.8219512 ,
#          0.45152416, -0.5303401 ],
#        [-0.17080535,  1.40705441, -1.18083057, ..., -0.3965614 ,
#          0.22000451, -0.5303401 ],
#        ...,
#        [-1.45100718, -0.07686519, -0.70929993, ...,  0.73781138,
#          0.93043194,  0.74288203],
#        [-1.88546393,  0.72445139, -0.76169222, ...,  1.80128587,
#          0.666655  , -0.03416625],
#        [-1.7722373 , -1.26400088,  1.07203802, ...,  0.52511649,
#          0.29909273,  0.74288203]])

# %% [markdown]
# Checking for Multicollinearity using Variance Inflation Factor

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
vif = pd.DataFrame()

# %%
vif["Features"] = X.columns
vif['vif'] = [variance_inflation_factor(scaled_X,i) for i in range(scaled_X.shape[1])]

# %%
vif
# Out:
#                 Features       vif
# 0          fixed acidity  6.870011
# 1       volatile acidity  1.837780
# 2            citric acid  2.966028
# 3         residual sugar  1.682277
# 4              chlorides  1.265877
# 5    free sulfur dioxide  2.820539
# 6   total sulfur dioxide  3.158303
# 7                density  5.582544
# 8                     pH  3.182893
# 9              sulphates  1.371917
# 10               alcohol  2.856852

# %% [markdown]
# fixed acidity' has a VIF value of 6.52 and 'density' has a VIF value of 5.90. Since the values are greater than 5, there is considerable multicollinearity. One of the features can be dropped based on which of the two has a lesser ANOVA f-value score.

# %% [markdown]
# ## Selecting Kbest Features

# %%
from sklearn.feature_selection import SelectKBest, f_classif

# %%
bestfeat = SelectKBest(score_func = f_classif, k = 11)
fit = bestfeat.fit(X,y)
dfscores = pd.DataFrame(fit.scores_)
dfcolumns = pd.DataFrame(X.columns)

# %%
fit = bestfeat.fit(X,y)
dfscores = pd.DataFrame(fit.scores_)
dfcolumns = pd.DataFrame(X.columns)
dfcolumns.head()
featureScores = pd.concat([dfcolumns,dfscores],axis = 1)
featureScores.columns = ['Feature', 'Score']
print(featureScores.nlargest(11,'Score'))
# Out:
#                  Feature       Score
# 10               alcohol  131.969660
# 9              sulphates   73.902370
# 1       volatile acidity   53.721566
# 6   total sulfur dioxide   29.074720
# 2            citric acid   25.557011
# 7                density   12.811245
# 4              chlorides   10.806954
# 0          fixed acidity    6.605673
# 5    free sulfur dioxide    6.263308
# 8                     pH    5.244225
# 3         residual sugar    1.837329

# %% [markdown]
# Selecting the best features based on their scores.

# %%
xbest = X.drop(columns = ['pH','residual sugar','fixed acidity'])

# %%
xbest
# Out:
#       volatile acidity  citric acid  chlorides  free sulfur dioxide  \
# 0                0.700         0.00  -0.145035            -0.241492
# 1                0.880         0.00   0.986838             1.091561
# 2                0.760         0.04   0.718578             0.238587
# 3                0.280         0.56  -0.207213             0.440493
# 4                0.700         0.00  -0.145035            -0.241492
# ...                ...          ...        ...                  ...
# 1594             0.600         0.08   0.622975             1.530980
# 1595             0.550         0.10  -1.120575             1.895825
# 1596             0.510         0.13  -0.145035             1.353642
# 1597             0.645         0.12  -0.207213             1.530980
# 1598             0.310         0.47  -0.744916             0.534239
#
#       total sulfur dioxide  density  sulphates   alcohol
# 0                -0.066536  0.99780  -0.589657 -1.120424
# 1                 0.952517  0.99680   0.451524 -0.530340
# 2                 0.624244  0.99700   0.220005 -0.530340
# 3                 0.784119  0.99800  -0.393177 -0.530340
# 4                -0.066536  0.99780  -0.589657 -1.120424
# ...                    ...      ...        ...       ...
# 1594              0.316130  0.99490  -0.393177  0.287037
# 1595              0.537893  0.99512   0.992572  0.901563
# 1596              0.173970  0.99574   0.930432  0.742882
# 1597              0.316130  0.99547   0.666655 -0.034166
# 1598              0.246643  0.99549   0.299093  0.742882
#
# [1451 rows x 8 columns]

# %%
scaled_X = scaler.fit_transform(xbest)

# %% [markdown]
# ## Classification Model Building

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix, roc_curve, roc_auc_score
from sklearn.metrics import classification_report
from sklearn.metrics import plot_roc_curve

# %%
from sklearn.ensemble import RandomForestClassifier
maxAcc = 0
maxRS=0
for i in range(1,100):
    x_train,x_test,y_train,y_test = train_test_split(scaled_X,y,test_size = .31, random_state = i)
    modRF =  RandomForestClassifier()
    modRF.fit(x_train,y_train)
    pred = modRF.predict(x_test)
    acc  = accuracy_score(y_test,pred)
    if acc>maxAcc:
        maxAcc=acc
        maxRS=i
print(f"Best Accuracy is: {maxAcc} on random_state: {maxRS}")
# Out:
# Best Accuracy is: 0.7444444444444445 on random_state: 27

# %% [markdown]
# Best Accuracy is: 0.8429203539823009 on random_state: 11

# %%
x_train,x_test,y_train,y_test = train_test_split(scaled_X,y,test_size = .30, random_state = 11)

# %%
# !pip install xgboost
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from xgboost import XGBClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
# Out:
# Requirement already satisfied: xgboost in c:\users\sourabh\anaconda3\lib\site-packages (1.4.2)
# Requirement already satisfied: numpy in c:\users\sourabh\anaconda3\lib\site-packages (from xgboost) (1.19.2)
# Requirement already satisfied: scipy in c:\users\sourabh\anaconda3\lib\site-packages (from xgboost) (1.5.2)

# %%
DTC = DecisionTreeClassifier()
RFC = RandomForestClassifier()
XGBC= XGBClassifier()
LOGR= LogisticRegression(solver='liblinear')
SV =  SVC()
KNN = KNeighborsClassifier()

# %% [markdown]
# ## Training the Models

# %%
DTC.fit(x_train,y_train)
RFC.fit(x_train,y_train)
XGBC.fit(x_train,y_train)
SV.fit(x_train,y_train)
LOGR.fit(x_train,y_train)
KNN.fit(x_train,y_train)
# Out:
# [23:36:55] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# KNeighborsClassifier()

# %% [markdown]
# All models have been trained.

# %% [markdown]
# ## Decision Tree Classifier Model Accuracy

# %%
DTCpred = DTC.predict(x_test)
accu = classification_report(y_test,DTCpred)

# %%
conf_matrx = confusion_matrix(y_test,DTCpred)

# %%
conf_matrx
# Out:
# array([[  1,   4,   3,   0,   0],
#        [  6, 131,  50,  11,   0],
#        [  3,  43, 113,  16,   1],
#        [  0,   9,  10,  31,   0],
#        [  0,   0,   1,   3,   0]], dtype=int64)

# %%
print(accu)
# Out:
#               precision    recall  f1-score   support
#
#            4       0.10      0.12      0.11         8
#            5       0.70      0.66      0.68       198
#            6       0.64      0.64      0.64       176
#            7       0.51      0.62      0.56        50
#            8       0.00      0.00      0.00         4
#
#     accuracy                           0.63       436
#    macro avg       0.39      0.41      0.40       436
# weighted avg       0.64      0.63      0.63       436

# %% [markdown]
# ## Logistic Regression Model Accuracy

# %%
LOGRpred = LOGR.predict(x_test)
accu = classification_report(y_test,LOGRpred)

# %%
conf_matrx = confusion_matrix(y_test,LOGRpred)
conf_matrx
# Out:
# array([[  0,   6,   2,   0,   0],
#        [  0, 143,  55,   0,   0],
#        [  0,  60, 112,   4,   0],
#        [  0,   2,  40,   8,   0],
#        [  0,   0,   2,   2,   0]], dtype=int64)

# %%
print(accu)
# Out:
#               precision    recall  f1-score   support
#
#            4       0.00      0.00      0.00         8
#            5       0.68      0.72      0.70       198
#            6       0.53      0.64      0.58       176
#            7       0.57      0.16      0.25        50
#            8       0.00      0.00      0.00         4
#
#     accuracy                           0.60       436
#    macro avg       0.36      0.30      0.31       436
# weighted avg       0.59      0.60      0.58       436

# %% [markdown]
# ## Random Forest Classifier Model Accuracy

# %%
RFCpred = RFC.predict(x_test)
accu = classification_report(y_test,RFCpred)

# %%
conf_matrx = confusion_matrix(y_test,RFCpred)
conf_matrx
# Out:
# array([[  0,   6,   2,   0,   0],
#        [  0, 154,  44,   0,   0],
#        [  0,  40, 129,   7,   0],
#        [  0,   2,  21,  27,   0],
#        [  0,   0,   1,   3,   0]], dtype=int64)

# %%
print(accu)
# Out:
#               precision    recall  f1-score   support
#
#            4       0.00      0.00      0.00         8
#            5       0.76      0.78      0.77       198
#            6       0.65      0.73      0.69       176
#            7       0.73      0.54      0.62        50
#            8       0.00      0.00      0.00         4
#
#     accuracy                           0.71       436
#    macro avg       0.43      0.41      0.42       436
# weighted avg       0.69      0.71      0.70       436

# %% [markdown]
# ## XGB Classifier Model Accuracy

# %%
XGBCpred = XGBC.predict(x_test)
accu = classification_report(y_test,XGBCpred)

# %%
conf_matrx = confusion_matrix(y_test,XGBCpred)
conf_matrx
# Out:
# array([[  1,   4,   3,   0,   0],
#        [  3, 142,  51,   2,   0],
#        [  2,  40, 121,  12,   1],
#        [  0,   3,  18,  29,   0],
#        [  0,   1,   2,   1,   0]], dtype=int64)

# %%
print(accu)
# Out:
#               precision    recall  f1-score   support
#
#            4       0.17      0.12      0.14         8
#            5       0.75      0.72      0.73       198
#            6       0.62      0.69      0.65       176
#            7       0.66      0.58      0.62        50
#            8       0.00      0.00      0.00         4
#
#     accuracy                           0.67       436
#    macro avg       0.44      0.42      0.43       436
# weighted avg       0.67      0.67      0.67       436

# %% [markdown]
# ## SV Classifier Model Accuracy

# %%
SVpred = SV.predict(x_test)
accu = classification_report(y_test,SVpred)

# %%
conf_matrx = confusion_matrix(y_test,SVpred)
conf_matrx
# Out:
# array([[  0,   5,   3,   0,   0],
#        [  0, 144,  53,   1,   0],
#        [  0,  57, 112,   7,   0],
#        [  0,   0,  35,  15,   0],
#        [  0,   0,   3,   1,   0]], dtype=int64)

# %%
print(accu)
# Out:
#               precision    recall  f1-score   support
#
#            4       0.00      0.00      0.00         8
#            5       0.70      0.73      0.71       198
#            6       0.54      0.64      0.59       176
#            7       0.62      0.30      0.41        50
#            8       0.00      0.00      0.00         4
#
#     accuracy                           0.62       436
#    macro avg       0.37      0.33      0.34       436
# weighted avg       0.61      0.62      0.61       436

# %% [markdown]
# ## K Nearest Neighbours Classifier Model Accuracy

# %%
KNNpred = KNN.predict(x_test)
accu = classification_report(y_test,KNNpred)

# %%
conf_matrx = confusion_matrix(y_test,KNNpred)
conf_matrx
# Out:
# array([[  1,   4,   2,   1,   0],
#        [  7, 132,  54,   5,   0],
#        [  1,  60,  94,  21,   0],
#        [  1,   8,  23,  18,   0],
#        [  0,   0,   1,   3,   0]], dtype=int64)

# %%
print(accu)
# Out:
#               precision    recall  f1-score   support
#
#            4       0.10      0.12      0.11         8
#            5       0.65      0.67      0.66       198
#            6       0.54      0.53      0.54       176
#            7       0.38      0.36      0.37        50
#            8       0.00      0.00      0.00         4
#
#     accuracy                           0.56       436
#    macro avg       0.33      0.34      0.33       436
# weighted avg       0.56      0.56      0.56       436

# %% [markdown]
# ## Model Cross Validation

# %%
from sklearn.model_selection import cross_val_score as cvs

# %% [markdown]
# Decision Tree Classifier

# %%
print(cvs(DTC,scaled_X,y,cv=5).mean())
# Out:
# 0.47345420073468414

# %% [markdown]
# Logistic Regression

# %%
print(cvs(LOGR,scaled_X,y,cv=5).mean())
# Out:
# 0.5810024884464984

# %% [markdown]
# Random Forest Classifier

# %%
print(cvs(RFC,scaled_X,y,cv=5).mean())
# Out:
# 0.5768929968005688

# %% [markdown]
# XGB Classifier

# %%
print(cvs(XGBC,scaled_X,y,cv=5).mean())
# Out:
# [23:38:47] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [23:38:48] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [23:38:49] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [23:38:51] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [23:38:51] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# 0.5403294229174073

# %% [markdown]
# SV Classifier

# %%
print(cvs(SV,scaled_X,y,cv=5).mean())
# Out:
# 0.5665339495200853

# %% [markdown]
# K Nearest Neighbours Classifier

# %%
print(cvs(KNN,scaled_X,y,cv=5).mean())
# Out:
# 0.5058679938381324

# %% [markdown]
# Based on comparing Accuracy Score results with Cross Validation results, it is determined that Logistic Regression is the best model.

# %% [markdown]
# ROC AUC Scores

# %% [markdown]
# Decision Tree Classifier

# %%
roc_auc_score(y_test,DTCpred)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-261-4957c6ee90a8> in <module>
# ----> 1 roc_auc_score(y_test,DTCpred)
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# ~\anaconda3\lib\site-packages\sklearn\metrics\_ranking.py in roc_auc_score(y_true, y_score, average, sample_weight, max_fpr, multi_class, labels)
#     534                              "instead".format(max_fpr))
#     535         if multi_class == 'raise':
# --> 536             raise ValueError("multi_class must be in ('ovo', 'ovr')")
#     537         return _multiclass_roc_auc_score(y_true, y_score, labels,
#     538                                          multi_class, average, sample_weight)
#
# ValueError: multi_class must be in ('ovo', 'ovr')

# %%
roc_auc_score(y_test,LOGRpred)

# %% [markdown]
# Hyper Parameter Tuning

# %% [markdown]
# Random Forest Classifier

# %%
from sklearn.model_selection import GridSearchCV

# %%
parameter = {'n_estimators':[30,50,60],'max_depth': [10,20,40,60,80],'min_samples_leaf':[5,10,15,20,30],'min_samples_split':[2,5,10,20],'criterion':['gini','entropy'],'max_features':["auto","sqrt","log2"]}

# %%
GridCV = GridSearchCV(RandomForestClassifier(),parameter,cv=5,n_jobs = -1)

# %%
GridCV.fit(x_train,y_train)

# %%
GridCV.best_params_

# %%
Best_mod = RandomForestClassifier(n_estimators = 50,criterion = 'entropy', max_depth= 60, max_features = 'sqrt',min_samples_leaf = 5, min_samples_split = 10)
Best_mod.fit(x_train,y_train)
rfpred = Best_mod.predict(x_test)
acc = accuracy_score(y_test,rfpred)
print(acc*100)

# %%
conf_matrx= confusion_matrix(y_test,rfpred)
conf_matrx
